# %% [markdown]
# <a href="https://colab.research.google.com/github/DouglasP15/Jokenpo/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# vamos colocar uma extensão no colab
# %load_ext NOME_DA_EXTEN
 # <<< carreamos nossa plataforma
# %load_ext sql
#tenho comando da extensão
#criar um banco de dados
# %sql sqlite:///nome_do_banco_de_dados.db
# %sql sqlite:///playlist.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# comanndos basicos de um banco de dados
# %%sql
create table minhaplaylist(
  id_minhaplaylist integer auto_increment primary key,
  musica text not null,
  artista text not null
);
# Out:
#  * sqlite:///playlist.db
# (sqlite3.OperationalError) table minhaplaylist already exists
# [SQL: create table minhaplaylist(
#   id_minhaplaylist integer auto_increment primary key,
#   musica text not null,
#   artista text not null
# );]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
print('----- MINHA PLAYLIST -----')

while True:
  musica = input('informe o nome da musica ')
  artista = input('informe o artista ')

  #vamos chamar nosso pass para salvar as infnormações
  #insert into nome_da_tabela (campos) values (valores)
  # %sql insert into minhaplaylist (musica, artista) values (:musica,:artista)
  print('informações adicionadas para o banco de dados')

  op = input('quer adicionar uma nova musica S/N')
  if op.lower()== 'n':
    break
# Out:
# ----- MINHA PLAYLIST -----
# informe o nome da musica Who Saays
# informe o artista Selena Gomez
#  * sqlite:///playlist.db
# 1 rows affected.
# informações adicionadas para o banco de dados
# quer adicionar uma nova musica S/Ns
# informe o nome da musica Go Away
# informe o artista 2NE1
#  * sqlite:///playlist.db
# 1 rows affected.
# informações adicionadas para o banco de dados
# quer adicionar uma nova musica S/NS
# informe o nome da musica Deja Vu
# informe o artista Beyonce
#  * sqlite:///playlist.db
# 1 rows affected.
# informações adicionadas para o banco de dados
# quer adicionar uma nova musica S/NS
# informe o nome da musica Always Be My Baby
# informe o artista Mariah Carey
#  * sqlite:///playlist.db
# 1 rows affected.
# informações adicionadas para o banco de dados
# quer adicionar uma nova musica S/Nn
